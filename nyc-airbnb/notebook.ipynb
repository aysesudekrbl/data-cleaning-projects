# %%
import pandas as pd

# %%
data = pd.read_csv("AB_NYC_2019.csv")

# %%
data.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 48895 entries, 0 to 48894
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              48895 non-null  int64
#  1   name                            48879 non-null  str
#  2   host_id                         48895 non-null  int64
#  3   host_name                       48874 non-null  str
#  4   neighbourhood_group             48895 non-null  str
#  5   neighbourhood                   48895 non-null  str
#  6   latitude                        48895 non-null  float64
#  7   longitude                       48895 non-null  float64
#  8   room_type                       48895 non-null  str
#  9   price                           48895 non-null  int64
#  10  minimum_nights                  48895 non-null  int64
#  11  number_of_reviews               48895 non-null  int64
# ...

# %%
data.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %%
data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                 10052
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
data.duplicated().sum()
# Out:
# np.int64(0)

# %%
data["price"].dtype
# Out:
# dtype('int64')

# %%
data["room_type"].unique()
# Out:
# <StringArray>
# ['Private room', 'Entire home/apt', 'Shared room']
# Length: 3, dtype: str

# %%
data[data["longitude"]> 0]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
data.columns
# Out:
# Index(['id', 'name', 'host_id', 'host_name', 'neighbourhood_group',
#        'neighbourhood', 'latitude', 'longitude', 'room_type', 'price',
#        'minimum_nights', 'number_of_reviews', 'last_review',
#        'reviews_per_month', 'calculated_host_listings_count',
#        'availability_365'],
#       dtype='str')

# %%
data[data["latitude"]< 0]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
data.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %%
data[data["availability_365"]>365]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
data[data["availability_365"] < 0]
# Out:
# Empty DataFrame
# Columns: [id, name, host_id, host_name, neighbourhood_group, neighbourhood, latitude, longitude, room_type, price, minimum_nights, number_of_reviews, last_review, reviews_per_month, calculated_host_listings_count, availability_365]
# Index: []

# %%
data['minimum_nights'].describe()
# Out:
# count    48895.000000
# mean         7.029962
# std         20.510550
# min          1.000000
# 25%          1.000000
# 50%          3.000000
# 75%          5.000000
# max       1250.000000
# Name: minimum_nights, dtype: float64

# %%
data[data['minimum_nights'] > 365]
# Out:
#              id                                 name    host_id   host_name  \
# 1305     568684  800sqft apartment with huge terrace    2798644  Alessandra
# 2854    1615764                                  NaN    6676776       Peter
# 5767    4204302     Prime W. Village location 1 bdrm   17550546   Genevieve
# 7355    5431845  Beautiful Fully Furnished 1 bed/bth    3680008       Aliya
# 8014    6169897            Wonderful Large 1 bedroom   10720264        John
# 10829   8341919  Brand New Luxury Apt Lease Takeover   43945071     Shining
# 11193   8668115   Zen Room in Crown Heights Brooklyn    8996336       Laura
# 13404  10053943   Historic Designer 2 Bed. Apartment    2697686    Glenn H.
# 14285  11096888      Peaceful apartment close to F/G    2228137      Amanda
# 15946  12888849   Bright Luxury Studio, Central Loc.   16476167       Sarah
# 26341  20990053      Beautiful place in Brooklyn! #2  151084261       Angie
# ...

# %%
data[data['minimum_nights'] > 365].shape[0]
# Out:
# 14

# %%
data[data['minimum_nights'] > 365][['minimum_nights','room_type', 'price', 'availability_365', 'number_of_reviews']]
# Out:
#        minimum_nights        room_type  price  availability_365  \
# 1305              370  Entire home/apt    115               365
# 2854             1000  Entire home/apt    400               362
# 5767             1250  Entire home/apt    180               365
# 7355              500  Entire home/apt    134                90
# 8014              500  Entire home/apt     75               362
# 10829             480  Entire home/apt    199               365
# 11193             500     Private room     50               365
# 13404             999  Entire home/apt     99                42
# 14285             500     Private room     45               358
# 15946             366  Entire home/apt    250               365
# 26341             999     Private room     79               249
# 34487             400     Private room     50                90
# 38664             999      Shared room    110               365
# 47620             500  Entire home/apt    140               331
#
# ...

# %%
data[data['reviews_per_month'].isnull()]['number_of_reviews'].value_counts()
# Out:
# number_of_reviews
# 0    10052
# Name: count, dtype: int64

# %%
data["reviews_per_month"] = data["reviews_per_month"].fillna(0)

# %%
data.isnull().sum()
# Out:
# id                                    0
# name                                 16
# host_id                               0
# host_name                            21
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
data["name"] = data["name"].fillna("Unknown")

# %%
data["host_name"] = data["host_name"].fillna("Unknown")

# %%
data.isnull().sum()
# Out:
# id                                    0
# name                                  0
# host_id                               0
# host_name                             0
# neighbourhood_group                   0
# neighbourhood                         0
# latitude                              0
# longitude                             0
# room_type                             0
# price                                 0
# minimum_nights                        0
# number_of_reviews                     0
# last_review                       10052
# reviews_per_month                     0
# calculated_host_listings_count        0
# availability_365                      0
# dtype: int64

# %%
import numpy as np

# %%
data["last_review"] = np.where(data["last_review"].isnull(), np.where(data["number_of_reviews"] == 0, "Doesn't exist", "Couldn't find"), data["last_review"])

# %%
data.isnull().sum()
# Out:
# id                                0
# name                              0
# host_id                           0
# host_name                         0
# neighbourhood_group               0
# neighbourhood                     0
# latitude                          0
# longitude                         0
# room_type                         0
# price                             0
# minimum_nights                    0
# number_of_reviews                 0
# last_review                       0
# reviews_per_month                 0
# calculated_host_listings_count    0
# availability_365                  0
# dtype: int64

# %%
data['is_unrealistic_min_nights'] = data['minimum_nights'] > data['availability_365']
data['minimum_nights_adjusted'] = data[['minimum_nights', 'availability_365']].min(axis=1)

# %%
data.head(10)
# Out:
#      id                                              name  host_id  \
# 0  2539                Clean & quiet apt home by the park     2787
# 1  2595                             Skylit Midtown Castle     2845
# 2  3647               THE VILLAGE OF HARLEM....NEW YORK !     4632
# 3  3831                   Cozy Entire Floor of Brownstone     4869
# 4  5022  Entire Apt: Spacious Studio/Loft by central park     7192
# 5  5099         Large Cozy 1 BR Apartment In Midtown East     7322
# 6  5121                                   BlissArtsSpace!     7356
# 7  5178                  Large Furnished Room Near B'way      8967
# 8  5203                Cozy Clean Guest Room - Family Apt     7490
# 9  5238                Cute & Cozy Lower East Side 1 bdrm     7549
#
#      host_name neighbourhood_group       neighbourhood  latitude  longitude  \
# 0         John            Brooklyn          Kensington  40.64749  -73.97237
# ...

# %%
data.to_csv('AB_NYC_2019_Cleaned.csv', index=False)
