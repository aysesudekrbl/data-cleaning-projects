# %%
import pandas as pd

# %%
dp = pd.read_csv("dirty_cafe_sales.csv")

# %%
dp.head()
# Out:
#   Transaction ID    Item Quantity Price Per Unit Total Spent  Payment Method  \
# 0    TXN_1961373  Coffee        2            2.0         4.0     Credit Card
# 1    TXN_4977031    Cake        4            3.0        12.0            Cash
# 2    TXN_4271903  Cookie        4            1.0       ERROR     Credit Card
# 3    TXN_7034554   Salad        2            5.0        10.0         UNKNOWN
# 4    TXN_3160411  Coffee        2            2.0         4.0  Digital Wallet
#
#    Location Transaction Date
# 0  Takeaway       2023-09-08
# 1  In-store       2023-05-16
# 2  In-store       2023-07-19
# 3   UNKNOWN       2023-04-27
# 4  In-store       2023-06-11

# %%
dp.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 10000 entries, 0 to 9999
# Data columns (total 8 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Transaction ID    10000 non-null  str
#  1   Item              9667 non-null   str
#  2   Quantity          9862 non-null   str
#  3   Price Per Unit    9821 non-null   str
#  4   Total Spent       9827 non-null   str
#  5   Payment Method    7421 non-null   str
#  6   Location          6735 non-null   str
#  7   Transaction Date  9841 non-null   str
# dtypes: str(8)
# memory usage: 625.1 KB

# %%
dp.columns
# Out:
# Index(['Transaction ID', 'Item', 'Quantity', 'Price Per Unit', 'Total Spent',
#        'Payment Method', 'Location', 'Transaction Date'],
#       dtype='str')

# %%
for x in dp.columns:
    print(dp[x].isnull().sum())
# Out:
# 0
# 333
# 138
# 179
# 173
# 2579
# 3265
# 159

# %%
print((dp["Quantity"].isnull() & dp["Price Per Unit"].isnull()).sum())
print((dp["Quantity"].isnull() & dp["Total Spent"].isnull()).sum())
print((dp["Price Per Unit"].isnull() & dp["Total Spent"].isnull()).sum())
# Out:
# 1
# 3
# 2

# %%
dp.groupby("Item")["Price Per Unit"].unique()
# Out:
# Item
# Cake                               [3.0, nan, UNKNOWN, ERROR]
# Coffee                             [2.0, nan, ERROR, UNKNOWN]
# Cookie                             [1.0, UNKNOWN, nan, ERROR]
# ERROR       [1.5, 3.0, 5.0, nan, 4.0, 2.0, 1.0, UNKNOWN, E...
# Juice                              [3.0, nan, UNKNOWN, ERROR]
# Salad                              [5.0, ERROR, UNKNOWN, nan]
# Sandwich                           [4.0, nan, ERROR, UNKNOWN]
# Smoothie                           [4.0, nan, UNKNOWN, ERROR]
# Tea                                [1.5, nan, ERROR, UNKNOWN]
# UNKNOWN     [3.0, 1.0, 5.0, 4.0, 1.5, 2.0, nan, UNKNOWN, E...
# Name: Price Per Unit, dtype: object

# %%
import numpy as np

# %%
dp = dp.replace(["UNKNOWN","ERROR"], np.nan)

# %%
dp.head(10)
# Out:
#   Transaction ID      Item Quantity Price Per Unit Total Spent  \
# 0    TXN_1961373    Coffee        2            2.0         4.0
# 1    TXN_4977031      Cake        4            3.0        12.0
# 2    TXN_4271903    Cookie        4            1.0         NaN
# 3    TXN_7034554     Salad        2            5.0        10.0
# 4    TXN_3160411    Coffee        2            2.0         4.0
# 5    TXN_2602893  Smoothie        5            4.0        20.0
# 6    TXN_4433211       NaN        3            3.0         9.0
# 7    TXN_6699534  Sandwich        4            4.0        16.0
# 8    TXN_4717867       NaN        5            3.0        15.0
# 9    TXN_2064365  Sandwich        5            4.0        20.0
#
#    Payment Method  Location Transaction Date
# 0     Credit Card  Takeaway       2023-09-08
# 1            Cash  In-store       2023-05-16
# 2     Credit Card  In-store       2023-07-19
# 3             NaN       NaN       2023-04-27
# ...

# %%
dp.isnull().sum()
# Out:
# Transaction ID         0
# Item                 969
# Quantity             479
# Price Per Unit       533
# Total Spent          502
# Payment Method      3178
# Location            3961
# Transaction Date     460
# dtype: int64

# %%
dp.groupby("Item")["Price Per Unit"].unique()
# Out:
# Item
# Cake        [3.0, nan]
# Coffee      [2.0, nan]
# Cookie      [1.0, nan]
# Juice       [3.0, nan]
# Salad       [5.0, nan]
# Sandwich    [4.0, nan]
# Smoothie    [4.0, nan]
# Tea         [1.5, nan]
# Name: Price Per Unit, dtype: object

# %%
type(dp["Price Per Unit"])
# Out:
# pandas.Series

# %%
dp["Price Per Unit"] = pd.to_numeric(dp["Price Per Unit"], errors="coerce")

# %%
price_dict = dp.groupby("Item")["Price Per Unit"].mean()

# %%
dp["Price Per Unit"] = dp["Price Per Unit"].fillna(dp["Item"].map(price_dict))

# %%
dp.tail(20)
# Out:
#      Transaction ID      Item Quantity  Price Per Unit Total Spent  \
# 9980    TXN_6796890       Tea        4             1.5         6.0
# 9981    TXN_4583012       NaN        5             4.0        20.0
# 9982    TXN_8567525    Cookie        2             1.0         2.0
# 9983    TXN_9226047  Smoothie        3             4.0        12.0
# 9984    TXN_3142496  Smoothie      NaN             4.0         4.0
# 9985    TXN_3297457      Cake        2             3.0         6.0
# 9986    TXN_2858441  Sandwich        2             4.0         8.0
# 9987    TXN_1784478     Juice        5             3.0        15.0
# 9988    TXN_9594133      Cake        5             3.0         NaN
# 9989    TXN_1741685     Juice        5             3.0        15.0
# 9990    TXN_1538510    Coffee        5             2.0        10.0
# 9991    TXN_3897619  Sandwich        3             4.0        12.0
# 9992    TXN_2739140  Smoothie        4             4.0        16.0
# ...

# %%
dp["Price Per Unit"].isnull().sum()
# Out:
# np.int64(54)

# %%
dp[dp["Price Per Unit"].isnull()]
# Out:
#      Transaction ID Item Quantity  Price Per Unit Total Spent  Payment Method  \
# 118     TXN_4633784  NaN        5             NaN        15.0             NaN
# 151     TXN_4031509  NaN        4             NaN        16.0     Credit Card
# 289     TXN_3495950  NaN        4             NaN         6.0     Credit Card
# 334     TXN_2523298  NaN        4             NaN         6.0             NaN
# 550     TXN_4186681  NaN        4             NaN         6.0  Digital Wallet
# 750     TXN_5787508  NaN        3             NaN         9.0     Credit Card
# 818     TXN_7940202  NaN        1             NaN         4.0  Digital Wallet
# 1154    TXN_2473090  NaN        2             NaN         3.0     Credit Card
# 1337    TXN_5031214  NaN        5             NaN         5.0             NaN
# 1377    TXN_8396271  NaN        2             NaN         2.0             NaN
# 1589    TXN_5245399  NaN        5             NaN        10.0             NaN
# ...

# %%
dp[dp["Price Per Unit"].isnull()][["Item", "Quantity", "Total Spent"]]
# Out:
#      Item Quantity Total Spent
# 118   NaN        5        15.0
# 151   NaN        4        16.0
# 289   NaN        4         6.0
# 334   NaN        4         6.0
# 550   NaN        4         6.0
# 750   NaN        3         9.0
# 818   NaN        1         4.0
# 1154  NaN        2         3.0
# 1337  NaN        5         5.0
# 1377  NaN        2         2.0
# 1589  NaN        5        10.0
# 1761  NaN        4         NaN
# 1786  NaN        4         6.0
# 2002  NaN        3         3.0
# 2227  NaN        2         8.0
# 2289  NaN        4         NaN
# 2596  NaN        5        15.0
# 2610  NaN        5        15.0
# 2962  NaN        4        16.0
# 3013  NaN        5        15.0
# 3404  NaN        5        10.0
# 3434  NaN        1         4.0
# 3666  NaN        2         3.0
# 3739  NaN        5        15.0
# 3779  NaN      NaN        25.0
# 3900  NaN        4         6.0
# 4092  NaN        1         5.0
# 4152  NaN        2         NaN
# 4621  NaN        2         6.0
# ...

# %%
dp = dp.drop([3779,7597,9819,4152,1761])

# %%
dp["Price Per Unit"].isnull().sum()
# Out:
# np.int64(49)

# %%
dp["Quantity"] = pd.to_numeric(dp["Quantity"], errors = "coerce")

# %%
dp["Total Spent"] = pd.to_numeric(dp["Total Spent"], errors = "coerce")

# %%
dp["Price Per Unit"] = dp["Price Per Unit"].fillna(dp["Total Spent"] / dp["Quantity"])

# %%
dp["Price Per Unit"].isnull().sum()
# Out:
# np.int64(1)

# %%
dp.isnull().sum()
# Out:
# Transaction ID         0
# Item                 964
# Quantity             476
# Price Per Unit         1
# Total Spent          500
# Payment Method      3176
# Location            3959
# Transaction Date     460
# dtype: int64

# %%
dp["Quantity"] = dp["Price Per Unit"].fillna(dp["Total Spent"] / dp["Price Per Unit"])

# %%
dp["Total Spent"] = dp["Price Per Unit"].fillna(dp["Quantity"] * dp["Price Per Unit"])

# %%
dp[dp["Price Per Unit"].isnull()][["Item", "Quantity", "Total Spent"]]
# Out:
#      Item  Quantity  Total Spent
# 2289  NaN       NaN          NaN

# %%
dp = dp.drop(2289)

# %%
dp.isnull().sum()
# Out:
# Transaction ID         0
# Item                 963
# Quantity               0
# Price Per Unit         0
# Total Spent            0
# Payment Method      3175
# Location            3958
# Transaction Date     460
# dtype: int64

# %%
price_dict.value_counts()
# Out:
# Price Per Unit
# 3.0    2
# 4.0    2
# 2.0    1
# 1.0    1
# 5.0    1
# 1.5    1
# Name: count, dtype: int64

# %%
dp[dp["Item"].isnull()]["Price Per Unit"].value_counts()
# Out:
# Price Per Unit
# 3.0    247
# 4.0    227
# 2.0    126
# 5.0    124
# 1.0    121
# 1.5    118
# Name: count, dtype: int64

# %%
dict_reversed = {v: k for k,v in price_dict.items()}

# %%
price_dict.value_counts()
# Out:
# Price Per Unit
# 3.0    2
# 4.0    2
# 2.0    1
# 1.0    1
# 5.0    1
# 1.5    1
# Name: count, dtype: int64

# %%
price_counts = price_dict.value_counts()

# %%
dict_reversed = {v: k for k,v in price_dict.items() if price_counts[v] == 1}

# %%
print(dict_reversed)
# Out:
# {2.0: 'Coffee', 1.0: 'Cookie', 5.0: 'Salad', 1.5: 'Tea'}

# %%
dp["Item"] = dp["Item"].fillna(dp["Price Per Unit"].map(dict_reversed))

# %%
dp.head(20)
# Out:
#    Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 0     TXN_1961373    Coffee       2.0             2.0          2.0
# 1     TXN_4977031      Cake       3.0             3.0          3.0
# 2     TXN_4271903    Cookie       1.0             1.0          1.0
# 3     TXN_7034554     Salad       5.0             5.0          5.0
# 4     TXN_3160411    Coffee       2.0             2.0          2.0
# 5     TXN_2602893  Smoothie       4.0             4.0          4.0
# 6     TXN_4433211       NaN       3.0             3.0          3.0
# 7     TXN_6699534  Sandwich       4.0             4.0          4.0
# 8     TXN_4717867       NaN       3.0             3.0          3.0
# 9     TXN_2064365  Sandwich       4.0             4.0          4.0
# 10    TXN_2548360     Salad       5.0             5.0          5.0
# 11    TXN_3051279  Sandwich       4.0             4.0          4.0
# 12    TXN_7619095  Sandwich       4.0             4.0          4.0
# ...

# %%
dp["Item"].isnull().sum()
# Out:
# np.int64(474)

# %%
dp["Item"] = dp["Item"].fillna("Unknown")

# %%
dp.isnull().sum()
# Out:
# Transaction ID         0
# Item                   0
# Quantity               0
# Price Per Unit         0
# Total Spent            0
# Payment Method      3175
# Location            3958
# Transaction Date     460
# dtype: int64

# %%
dp.sort_values("Transaction ID")
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 2987    TXN_1000555       Tea       1.5             1.5          1.5
# 115     TXN_1001832     Salad       5.0             5.0          5.0
# 418     TXN_1002457    Cookie       1.0             1.0          1.0
# 3417    TXN_1003246     Juice       3.0             3.0          3.0
# 4366    TXN_1004184  Smoothie       4.0             4.0          4.0
# ...             ...       ...       ...             ...          ...
# 1389    TXN_9996968  Sandwich       4.0             4.0          4.0
# 7964    TXN_9997263    Cookie       1.0             1.0          1.0
# 4304    TXN_9997620    Cookie       1.0             1.0          1.0
# 98      TXN_9999113     Juice       3.0             3.0          3.0
# 5037    TXN_9999124     Juice       3.0             3.0          3.0
#
#       Payment Method  Location Transaction Date
# 2987     Credit Card  In-store       2023-10-19
# ...

# %%
dp.groupby("Location")["Item"].value_counts()
# Out:
# Location  Item
# In-store  Salad       406
#           Cookie      373
#           Sandwich    370
#           Tea         369
#           Juice       361
#           Coffee      352
#           Smoothie    322
#           Cake        321
#           Unknown     140
# Takeaway  Cookie      402
#           Coffee      396
#           Salad       378
#           Tea         368
#           Sandwich    345
#           Cake        343
#           Juice       341
#           Smoothie    304
#           Unknown     145
# Name: count, dtype: int64

# %%
dp.groupby("Payment Method")["Item"].value_counts()
# Out:
# Payment Method  Item
# Cash            Salad       316
#                 Cake        276
#                 Cookie      274
#                 Coffee      266
#                 Juice       266
#                 Tea         264
#                 Sandwich    253
#                 Smoothie    236
#                 Unknown     107
# Credit Card     Salad       306
#                 Cookie      279
#                 Juice       276
#                 Coffee      275
#                 Tea         261
#                 Sandwich    256
#                 Cake        253
#                 Smoothie    252
#                 Unknown     113
# Digital Wallet  Coffee      295
#                 Cookie      291
#                 Juice       285
#                 Tea         279
#                 Salad       274
#                 Sandwich    255
#                 Smoothie    255
#                 Cake        246
#                 Unknown     110
# Name: count, dtype: int64

# %%
dp.groupby("Payment Method")["Location"].value_counts()
# Out:
# Payment Method  Location
# Cash            In-store    702
#                 Takeaway    664
# Credit Card     In-store    681
#                 Takeaway    669
# Digital Wallet  Takeaway    744
#                 In-store    694
# Name: count, dtype: int64

# %%
dp.groupby("Location")["Item"].value_counts()
# Out:
# Location  Item
# In-store  Salad       406
#           Cookie      373
#           Sandwich    370
#           Tea         369
#           Juice       361
#           Coffee      352
#           Smoothie    322
#           Cake        321
#           Unknown     140
# Takeaway  Cookie      402
#           Coffee      396
#           Salad       378
#           Tea         368
#           Sandwich    345
#           Cake        343
#           Juice       341
#           Smoothie    304
#           Unknown     145
# Name: count, dtype: int64

# %%
dp["Location"] = dp["Location"].fillna("Unknown")

# %%
dp["Payment Method"] = dp["Payment Method"].fillna("Unknown")

# %%
dp.tail(20)
# Out:
#      Transaction ID      Item  Quantity  Price Per Unit  Total Spent  \
# 9980    TXN_6796890       Tea       1.5             1.5          1.5
# 9981    TXN_4583012   Unknown       4.0             4.0          4.0
# 9982    TXN_8567525    Cookie       1.0             1.0          1.0
# 9983    TXN_9226047  Smoothie       4.0             4.0          4.0
# 9984    TXN_3142496  Smoothie       4.0             4.0          4.0
# 9985    TXN_3297457      Cake       3.0             3.0          3.0
# 9986    TXN_2858441  Sandwich       4.0             4.0          4.0
# 9987    TXN_1784478     Juice       3.0             3.0          3.0
# 9988    TXN_9594133      Cake       3.0             3.0          3.0
# 9989    TXN_1741685     Juice       3.0             3.0          3.0
# 9990    TXN_1538510    Coffee       2.0             2.0          2.0
# 9991    TXN_3897619  Sandwich       4.0             4.0          4.0
# 9992    TXN_2739140  Smoothie       4.0             4.0          4.0
# ...

# %%
dp["Transaction Date"].dtype
# Out:
# <StringDtype(storage='python', na_value=nan)>

# %%
dp["Transaction Date"] = dp["Transaction Date"].fillna("Unknown")

# %%
dp.isnull().sum()
# Out:
# Transaction ID      0
# Item                0
# Quantity            0
# Price Per Unit      0
# Total Spent         0
# Payment Method      0
# Location            0
# Transaction Date    0
# dtype: int64

# %%
dp = dp.sort_values("Transaction ID")

# %%
dp.to_csv("cafe_sales_cleaned.csv", index=False)
